# %% [markdown]
# # **APRENDIZAGEM NÃO SUPERVISIONADA: ASSOCIAÇÃO**

# %% [markdown]
# Este projeto tem por objetivo desenvolver um algoritmo de Machine Learning para associar produtos de mercado.

# %% [markdown]
# Os dados foram extraídos do site do Kaggle:
#
# https://www.kaggle.com/heeraldedhia/groceries-dataset

# %%
import numpy as np
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('./Groceries_dataset.csv',
                    sep=',', encoding='iso-8859-1')

# %%
df.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
df.shape
# Out:
# (38765, 3)

# %% [markdown]
# ## **ANÁLISE, TRATAMENTO E PRÉ-PROCESSAMENTO DOS DADOS**

# %% [markdown]
# **Valores Missing (NAN)**

# %%
# RELAÇÃO DA QUANTIDADE
df.isnull().sum()
# Out:
# Member_number      0
# Date               0
# itemDescription    0
# dtype: int64

# %% [markdown]
# **Análise dos tipos de atributos.**

# %%
# object: strings
# int64: inteiros
# float64: reais
# complex: complexos
df.dtypes
# Out:
# Member_number       int64
# Date               object
# itemDescription    object
# dtype: object

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
df.dtypes
# Out:
# Member_number               int64
# Date               datetime64[ns]
# itemDescription            object
# dtype: object

# %%
df["itemDescription"].value_counts().head(30)
# Out:
# itemDescription
# whole milk               2502
# other vegetables         1898
# rolls/buns               1716
# soda                     1514
# yogurt                   1334
# root vegetables          1071
# tropical fruit           1032
# bottled water             933
# sausage                   924
# citrus fruit              812
# pastry                    785
# pip fruit                 744
# shopping bags             731
# canned beer               717
# bottled beer              687
# whipped/sour cream        662
# newspapers                596
# frankfurter               580
# brown bread               571
# pork                      566
# domestic eggs             566
# butter                    534
# fruit/vegetable juice     518
# beef                      516
# curd                      514
# margarine                 491
# coffee                    476
# frozen vegetables         425
# chicken                   422
# white bread               362
# Name: count, dtype: int64

# %%
df["Member_number"].value_counts().head(10)
# Out:
# Member_number
# 3180    36
# 3737    33
# 3050    33
# 2051    33
# 2625    31
# 3915    31
# 2433    31
# 2271    31
# 3872    30
# 3289    29
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Member_number       Date   itemDescription
# 0           1808 2015-07-21    tropical fruit
# 1           2552 2015-01-05        whole milk
# 2           2300 2015-09-19         pip fruit
# 3           1187 2015-12-12  other vegetables
# 4           3037 2015-02-01        whole milk

# %%
df2 = df.groupby(['Member_number', 'itemDescription'])['itemDescription'].count().unstack().fillna(0).applymap(
    lambda x: 1 if x > 0 else 0)

# %%
df2
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                                 0         0                 0
# 1001                                 0         0                 0
# 1002                                 0         0                 0
# 1003                                 0         0                 0
# 1004                                 0         0                 0
# ...                                ...       ...               ...
# 4996                                 0         0                 0
# 4997                                 0         0                 0
# 4998                                 0         0                 0
# 4999                                 0         0                 0
# 5000                                 0         0                 0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# 1000                            0               0     0              0
# 1001                            0               0     0              0
# 1002                            0               0     0              0
# 1003                            0               0     0              0
# 1004                            0               0     0              0
# ...                           ...             ...   ...            ...
# 4996                            0               0     0              0
# 4997                            0               0     0              0
# 4998                            0               0     0              0
# 4999                            0               0     0              0
# 5000                            0               0     0              0
#
# itemDescription  bathroom cleaner  beef  berries  ...  turkey  vinegar  \
# Member_number                                     ...
# 1000                            0     0        0  ...       0        0
# 1001                            0     1        0  ...       0        0
# 1002                            0     0        0  ...       0        0
# 1003                            0     0        0  ...       0        0
# 1004                            0     0        0  ...       0        0
# ...                           ...   ...      ...  ...     ...      ...
# 4996                            0     0        0  ...       0        0
# 4997                            0     0        0  ...       0        0
# 4998                            0     0        0  ...       0        0
# 4999                            0     0        1  ...       0        0
# 5000                            0     0        0  ...       0        0
#
# itemDescription  waffles  whipped/sour cream  whisky  white bread  white wine  \
# Member_number
# 1000                   0                   0       0            0           0
# 1001                   0                   1       0            1           0
# 1002                   0                   0       0            0           0
# 1003                   0                   0       0            0           0
# 1004                   0                   0       0            0           0
# ...                  ...                 ...     ...          ...         ...
# 4996                   0                   0       0            0           0
# 4997                   0                   0       0            0           1
# 4998                   0                   0       0            0           0
# 4999                   0                   1       0            0           0
# 5000                   0                   0       0            0           0
#
# itemDescription  whole milk  yogurt  zwieback
# Member_number
# 1000                      1       1         0
# 1001                      1       0         0
# 1002                      1       0         0
# 1003                      0       0         0
# 1004                      1       0         0
# ...                     ...     ...       ...
# 4996                      0       0         0
# 4997                      1       0         0
# 4998                      0       0         0
# 4999                      0       1         0
# 5000                      0       0         0
#
# [3898 rows x 167 columns]

# %%
df2.iloc[0:12, 0:12]
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                                 0         0                 0
# 1001                                 0         0                 0
# 1002                                 0         0                 0
# 1003                                 0         0                 0
# 1004                                 0         0                 0
# 1005                                 0         0                 0
# 1006                                 0         0                 0
# 1008                                 0         0                 0
# 1009                                 0         0                 0
# 1010                                 0         1                 0
# 1011                                 0         0                 0
# 1012                                 0         0                 0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# 1000                            0               0     0              0
# 1001                            0               0     0              0
# 1002                            0               0     0              0
# 1003                            0               0     0              0
# 1004                            0               0     0              0
# 1005                            0               0     0              0
# 1006                            0               0     0              0
# 1008                            0               0     0              0
# 1009                            0               0     0              0
# 1010                            0               0     0              0
# 1011                            0               0     0              0
# 1012                            0               0     0              0
#
# itemDescription  bathroom cleaner  beef  berries  beverages  bottled beer
# Member_number
# 1000                            0     0        0          0             0
# 1001                            0     1        0          0             0
# 1002                            0     0        0          0             0
# 1003                            0     0        0          0             0
# 1004                            0     0        0          0             0
# 1005                            0     0        0          0             0
# 1006                            0     0        0          0             1
# 1008                            0     0        0          0             0
# 1009                            0     0        0          0             0
# 1010                            0     0        0          0             0
# 1011                            0     0        0          0             0
# 1012                            0     0        0          0             0

# %%
df2.shape
# Out:
# (3898, 167)

# %% [markdown]
# ## **APRIORI**

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Gerando a associação
associacao = apriori(df2, min_support=0.05, use_colnames=True)
# Out:
# /home/mrzebodexxsz/anaconda3/lib/python3.11/site-packages/mlxtend/frequent_patterns/fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
# Colocando em ordem dos mais frequentes
associacao.sort_values("support", ascending=False).head(10)
# Out:
#       support                        itemsets
# 55   0.458184                    (whole milk)
# 37   0.376603              (other vegetables)
# 41   0.349666                    (rolls/buns)
# 47   0.313494                          (soda)
# 56   0.282966                        (yogurt)
# 51   0.233710                (tropical fruit)
# 42   0.230631               (root vegetables)
# 5    0.213699                 (bottled water)
# 44   0.206003                       (sausage)
# 116  0.191380  (other vegetables, whole milk)

# %%
# Criando as regras de associação
regras = association_rules(associacao, metric="lift")

# %%
# Colocando em ordem de suporte, confiança ou grau de associação (Lift)
resultado = regras.sort_values("support", ascending=False)

# %%
resultado.head(20)
# Out:
#             antecedents         consequents  antecedent support  \
# 118  (other vegetables)        (whole milk)            0.376603
# 119        (whole milk)  (other vegetables)            0.458184
# 152        (rolls/buns)        (whole milk)            0.349666
# 153        (whole milk)        (rolls/buns)            0.458184
# 182              (soda)        (whole milk)            0.313494
# 183        (whole milk)              (soda)            0.458184
# 193        (whole milk)            (yogurt)            0.458184
# 192            (yogurt)        (whole milk)            0.282966
# 105  (other vegetables)        (rolls/buns)            0.376603
# 104        (rolls/buns)  (other vegetables)            0.349666
# 113  (other vegetables)              (soda)            0.376603
# 112              (soda)  (other vegetables)            0.313494
# 121  (other vegetables)            (yogurt)            0.376603
# 120            (yogurt)  (other vegetables)            0.282966
# 146        (rolls/buns)              (soda)            0.349666
# 147              (soda)        (rolls/buns)            0.313494
# 187        (whole milk)    (tropical fruit)            0.458184
# 186    (tropical fruit)        (whole milk)            0.233710
# 163        (whole milk)   (root vegetables)            0.458184
# 162   (root vegetables)        (whole milk)            0.230631
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 118            0.458184  0.191380    0.508174  1.109106  0.018827    1.101643
# 119            0.376603  0.191380    0.417693  1.109106  0.018827    1.070564
# 152            0.458184  0.178553    0.510638  1.114484  0.018342    1.107190
# 153            0.349666  0.178553    0.389698  1.114484  0.018342    1.065592
# 182            0.458184  0.151103    0.481997  1.051973  0.007465    1.045971
# 183            0.313494  0.151103    0.329787  1.051973  0.007465    1.024310
# 193            0.282966  0.150590    0.328667  1.161510  0.020940    1.068076
# 192            0.458184  0.150590    0.532185  1.161510  0.020940    1.158185
# 105            0.349666  0.146742    0.389646  1.114335  0.015056    1.065502
# 104            0.376603  0.146742    0.419663  1.114335  0.015056    1.074197
# 113            0.313494  0.124166    0.329700  1.051695  0.006103    1.024178
# 112            0.376603  0.124166    0.396072  1.051695  0.006103    1.032237
# 121            0.282966  0.120318    0.319482  1.129050  0.013752    1.053660
# 120            0.376603  0.120318    0.425204  1.129050  0.013752    1.084553
# 146            0.313494  0.119805    0.342627  1.092928  0.010187    1.044316
# 147            0.349666  0.119805    0.382160  1.092928  0.010187    1.052593
# 187            0.233710  0.116470    0.254199  1.087672  0.009388    1.027473
# 186            0.458184  0.116470    0.498353  1.087672  0.009388    1.080076
# 163            0.230631  0.113135    0.246920  1.070630  0.007464    1.021630
# 162            0.458184  0.113135    0.490545  1.070630  0.007464    1.063522
#
#      zhangs_metric
# 118       0.157802
# 119       0.181562
# 152       0.157955
# 153       0.189591
# 182       0.071966
# 183       0.091184
# 193       0.256640
# 192       0.193926
# 105       0.164589
# 104       0.157772
# 113       0.078849
# 112       0.071601
# 121       0.183350
# 120       0.159406
# 146       0.130743
# 147       0.123855
# 187       0.148768
# 186       0.105189
# 163       0.121758
# 162       0.085746

# %% [markdown]
# ## **DESAFIO 6**

# %% [markdown]
# Desenvolver os algoritmos Apriori e Eclat utilizando o Exemplo 2 disponível na biblioteca pyECLAT.

# %%
# !pip install pyECLAT
# Out:
# Requirement already satisfied: pyECLAT in /home/mrzebodexxsz/anaconda3/lib/python3.11/site-packages (1.0.2)
# Requirement already satisfied: pandas>=0.25.3 in /home/mrzebodexxsz/anaconda3/lib/python3.11/site-packages (from pyECLAT) (2.1.4)
# Requirement already satisfied: numpy>=1.17.4 in /home/mrzebodexxsz/anaconda3/lib/python3.11/site-packages (from pyECLAT) (1.26.4)
# Requirement already satisfied: tqdm>=4.41.1 in /home/mrzebodexxsz/anaconda3/lib/python3.11/site-packages (from pyECLAT) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mrzebodexxsz/anaconda3/lib/python3.11/site-packages (from pandas>=0.25.3->pyECLAT) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/mrzebodexxsz/anaconda3/lib/python3.11/site-packages (from pandas>=0.25.3->pyECLAT) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/mrzebodexxsz/anaconda3/lib/python3.11/site-packages (from pandas>=0.25.3->pyECLAT) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/mrzebodexxsz/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.25.3->pyECLAT) (1.16.0)

# %%
from pyECLAT import Example2
dados = Example2().get()
dados
# Out:
#                       0                  1                  2  \
# 0                shrimp            almonds            avocado
# 1               burgers          meatballs               eggs
# 2               chutney                NaN                NaN
# 3                turkey            avocado                NaN
# 4         mineral water               milk         energy bar
# ...                 ...                ...                ...
# 2996          green tea                NaN                NaN
# 2997             shrimp               cake                NaN
# 2998                ham        ground beef      mineral water
# 2999            burgers  frozen vegetables  whole wheat pasta
# 3000  whole wheat pasta               eggs               cake
#
#                      3             4                 5            6
# 0       vegetables mix  green grapes  whole weat flour         yams
# 1                  NaN           NaN               NaN          NaN
# 2                  NaN           NaN               NaN          NaN
# 3                  NaN           NaN               NaN          NaN
# 4     whole wheat rice     green tea               NaN          NaN
# ...                ...           ...               ...          ...
# 2996               NaN           NaN               NaN          NaN
# 2997               NaN           NaN               NaN          NaN
# 2998               NaN           NaN               NaN          NaN
# 2999     mineral water     chocolate              eggs  blueberries
# 3000      french fries     green tea               NaN          NaN
#
# [3001 rows x 7 columns]
